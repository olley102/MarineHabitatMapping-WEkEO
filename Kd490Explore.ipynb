# %%
import xarray as xr

# %%
# Define file path for KD490 data
file_path = "/home/jovyan/eodata/CMEMS/NRT/ATL/OPT/OCEANCOLOUR_ATL_OPTICS_L4_NRT_OBSERVATIONS_009_092/2020/06/01/20200601_m_20200630-OC_PML-L4-KD490-ok2_Oa_1KM-ATL-DT-v01.nc"

# %%
kd490_data = xr.open_dataset(file_path)

# %%
print(kd490_data)
# Out:
# <xarray.Dataset> Size: 300MB
# Dimensions:       (latitude: 4416, longitude: 5664, time: 1, nv: 2)
# Coordinates:
#   * latitude      (latitude) float32 18kB 65.99 65.98 65.97 ... 20.02 20.01
#   * longitude     (longitude) float32 23kB -45.99 -45.98 -45.97 ... 12.98 12.99
#   * time          (time) datetime64[ns] 8B 2020-06-01
#   * nv            (nv) int32 8B 0 1
# Data variables:
#     grid_mapping  int32 4B ...
#     KD490         (time, latitude, longitude) float32 100MB ...
#     KD490_count   (time, latitude, longitude) float32 100MB ...
#     KD490_error   (time, latitude, longitude) float32 100MB ...
#     time_bounds   (time, nv) datetime64[ns] 16B ...
# Attributes: (12/40)
#     file_quality_index:      0
#     product_level:           4
#     comment:
#     distribution_statement:  Copernicus Marine data license (see website)
#     site_name:               ATL
#     parameter_code:          KD490
#     ...                      ...
# ...

# %%
import matplotlib.pyplot as plt

# %%
kd490 = kd490_data['KD490']

# %%
kd490.isel(time=0).plot(cmap='viridis')
